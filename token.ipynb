# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhonn2021/Na-ve-Bees_-Deep-Learning-with-Images/blob/master/token.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('cess_esp')
# Out:
# [nltk_data] Downloading package cess_esp to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cess_esp.zip.
# True

# %%
import re
corpus = nltk.corpus.cess_esp.sents()
print(corpus)
# Out:
# [['El', 'grupo', 'estatal', 'Electricité_de_France', '-Fpa-', 'EDF', '-Fpt-', 'anunció', 'hoy', ',', 'jueves', ',', 'la', 'compra', 'del', '51_por_ciento', 'de', 'la', 'empresa', 'mexicana', 'Electricidad_Águila_de_Altamira', '-Fpa-', 'EAA', '-Fpt-', ',', 'creada', 'por', 'el', 'japonés', 'Mitsubishi_Corporation', 'para', 'poner_en_marcha', 'una', 'central', 'de', 'gas', 'de', '495', 'megavatios', '.'], ['Una', 'portavoz', 'de', 'EDF', 'explicó', 'a', 'EFE', 'que', 'el', 'proyecto', 'para', 'la', 'construcción', 'de', 'Altamira_2', ',', 'al', 'norte', 'de', 'Tampico', ',', 'prevé', 'la', 'utilización', 'de', 'gas', 'natural', 'como', 'combustible', 'principal', 'en', 'una', 'central', 'de', 'ciclo', 'combinado', 'que', 'debe', 'empezar', 'a', 'funcionar', 'en', 'mayo_del_2002', '.'], ...]

# %%
flatten = [w for l in corpus for w in l]
print(len(flatten))
# Out:
# 192685

# %%
print(flatten[:20])
# Out:
# ['El', 'grupo', 'estatal', 'Electricité_de_France', '-Fpa-', 'EDF', '-Fpt-', 'anunció', 'hoy', ',', 'jueves', ',', 'la', 'compra', 'del', '51_por_ciento', 'de', 'la', 'empresa', 'mexicana']

# %%
arr = [w for w in flatten if re.search('es',w)]

# %%
print(arr[:5])
# Out:
# ['estatal', 'jueves', 'empresa', 'centrales', 'francesa']

# %%
arr = [w for w in flatten if re.search('es$',w)]
print(arr[:5])
# Out:
# ['jueves', 'centrales', 'millones', 'millones', 'dólares']

# %%
arr = [w for w in flatten if re.search('^es',w)]
print(arr[:5])
# Out:
# ['estatal', 'es', 'esta', 'esta', 'eso']

# %%
#Rangos: [a-z] [ghi]
arr = [w for w in flatten if re.search('^[ghi]',w)]
print(arr[0:5])
# Out:
# ['grupo', 'hoy', 'gas', 'gas', 'intervendrá']

# %%
#Clausuras: * repetir 0 o mas veces; + repetir 1 o mas veces
arr = [w for w in flatten if re.search('^[no]*',w)]
print(arr[:20])
# Out:
# ['El', 'grupo', 'estatal', 'Electricité_de_France', '-Fpa-', 'EDF', '-Fpt-', 'anunció', 'hoy', ',', 'jueves', ',', 'la', 'compra', 'del', '51_por_ciento', 'de', 'la', 'empresa', 'mexicana']

# %%
arr = [w for w in flatten if re.search('^[no]+',w)]
print(arr[:20])
# Out:
# ['norte', 'natural', 'no', 'natural', 'no', 'o', 'noche', 'no', 'otros', 'no', 'número', 'ofreció', 'notificación', 'operación', 'ofrece', 'ofrece', 'ofrecen', 'nueva', 'operación', 'operación']

# %%
#raw
print('Esto es una \n prueba')
print(r'Esto es una \n prueba')
# Out:
# Esto es una
#  prueba
# Esto es una \n prueba

# %%
texto = """ En el día 200 del Estado de Emergencia debido a la pandemia del nuevo coronavirus (COVID-19) en el país, 
la ministra de Salud, Pilar Mazzetti, señaló esta mañana que los índices de mortalidad en pacientes afectados 
que estuvieron hospitalizados disminuyó en las últimas semanas.

En conversación con TV Perú, la titular del Ministerio de Salud consideró que uno de los factores de esta reducción
 es porque se está brindando una mejor atención que genera un mayor número de personas dadas de alta.

“Estamos analizando qué cosas han dado resultado a los pacientes en estos seis meses. Como ustedes habrán visto la
 mortalidad a raíz de la COVID-19 en hospitalización ha bajado en los últimos meses porque la atención está siendo mejor,
  y cada vez podemos dar de alta a las personas”, manifestó."""

# %%
#Caso 1: Tokenizar por espacios vacios
print(re.split(r' ',texto))
# Out:
# ['', 'En', 'el', 'día', '200', 'del', 'Estado', 'de', 'Emergencia', 'debido', 'a', 'la', 'pandemia', 'del', 'nuevo', 'coronavirus', '(COVID-19)', 'en', 'el', 'país,', '\nla', 'ministra', 'de', 'Salud,', 'Pilar', 'Mazzetti,', 'señaló', 'esta', 'mañana', 'que', 'los', 'índices', 'de', 'mortalidad', 'en', 'pacientes', 'afectados', '\nque', 'estuvieron', 'hospitalizados', 'disminuyó', 'en', 'las', 'últimas', 'semanas.\n\nEn', 'conversación', 'con', 'TV', 'Perú,', 'la', 'titular', 'del', 'Ministerio', 'de', 'Salud', 'consideró', 'que', 'uno', 'de', 'los', 'factores', 'de', 'esta', 'reducción\n', 'es', 'porque', 'se', 'está', 'brindando', 'una', 'mejor', 'atención', 'que', 'genera', 'un', 'mayor', 'número', 'de', 'personas', 'dadas', 'de', 'alta.\n\n“Estamos', 'analizando', 'qué', 'cosas', 'han', 'dado', 'resultado', 'a', 'los', 'pacientes', 'en', 'estos', 'seis', 'meses.', 'Como', 'ustedes', 'habrán', 'visto', 'la\n', 'mortalidad', 'a', 'raíz', 'de', 'la', 'COVID-19', 'en', 'hospitalizaci
# ...

# %%
#Caso2: Tokenizar con Regex
print(re.split(r'[ \t\n]+',texto))
# Out:
# ['', 'En', 'el', 'día', '200', 'del', 'Estado', 'de', 'Emergencia', 'debido', 'a', 'la', 'pandemia', 'del', 'nuevo', 'coronavirus', '(COVID-19)', 'en', 'el', 'país,', 'la', 'ministra', 'de', 'Salud,', 'Pilar', 'Mazzetti,', 'señaló', 'esta', 'mañana', 'que', 'los', 'índices', 'de', 'mortalidad', 'en', 'pacientes', 'afectados', 'que', 'estuvieron', 'hospitalizados', 'disminuyó', 'en', 'las', 'últimas', 'semanas.', 'En', 'conversación', 'con', 'TV', 'Perú,', 'la', 'titular', 'del', 'Ministerio', 'de', 'Salud', 'consideró', 'que', 'uno', 'de', 'los', 'factores', 'de', 'esta', 'reducción', 'es', 'porque', 'se', 'está', 'brindando', 'una', 'mejor', 'atención', 'que', 'genera', 'un', 'mayor', 'número', 'de', 'personas', 'dadas', 'de', 'alta.', '“Estamos', 'analizando', 'qué', 'cosas', 'han', 'dado', 'resultado', 'a', 'los', 'pacientes', 'en', 'estos', 'seis', 'meses.', 'Como', 'ustedes', 'habrán', 'visto', 'la', 'mortalidad', 'a', 'raíz', 'de', 'la', 'COVID-19', 'en', 'hospitalización', 'ha
# ...

# %%
#Caso 3: Tokenizar con regex
print(re.split(r'[ \W\t\n]+', texto))
# Out:
# ['', 'En', 'el', 'día', '200', 'del', 'Estado', 'de', 'Emergencia', 'debido', 'a', 'la', 'pandemia', 'del', 'nuevo', 'coronavirus', 'COVID', '19', 'en', 'el', 'país', 'la', 'ministra', 'de', 'Salud', 'Pilar', 'Mazzetti', 'señaló', 'esta', 'mañana', 'que', 'los', 'índices', 'de', 'mortalidad', 'en', 'pacientes', 'afectados', 'que', 'estuvieron', 'hospitalizados', 'disminuyó', 'en', 'las', 'últimas', 'semanas', 'En', 'conversación', 'con', 'TV', 'Perú', 'la', 'titular', 'del', 'Ministerio', 'de', 'Salud', 'consideró', 'que', 'uno', 'de', 'los', 'factores', 'de', 'esta', 'reducción', 'es', 'porque', 'se', 'está', 'brindando', 'una', 'mejor', 'atención', 'que', 'genera', 'un', 'mayor', 'número', 'de', 'personas', 'dadas', 'de', 'alta', 'Estamos', 'analizando', 'qué', 'cosas', 'han', 'dado', 'resultado', 'a', 'los', 'pacientes', 'en', 'estos', 'seis', 'meses', 'Como', 'ustedes', 'habrán', 'visto', 'la', 'mortalidad', 'a', 'raíz', 'de', 'la', 'COVID', '19', 'en', 'hospitalización', 'ha', '
# ...

# %%
texto = 'En los E.U. esa postal vale $15.50 ...'

# %%
print(re.split(r'[ \W\t\n]+', texto))
# Out:
# ['En', 'los', 'E', 'U', 'esa', 'postal', 'vale', '15', '50', '']

# %%
pattern = r'''(?x)                  # Flag para iniciar el modo verbose
              (?:[A-Z]\.)+          # Hace match con abreviaciones como U.S.A.
              | \w+(?:-\w+)*        # Hace match con palabras que pueden tener un guión interno
              | \$?\d+(?:\.\d+)?%?  # Hace match con dinero o porcentajes como $15.5 o 100%
              | \.\.\.              # Hace match con puntos suspensivos
              | [][.,;"'?():-_`]    # Hace match con signos de puntuación
'''
nltk.regexp_tokenize(texto,pattern)
# Out:
# ['En', 'los', 'E.U.', 'esa', 'postal', 'vale', '$15.50', '...']

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-edf56eb9-e136-4366-995d-696368da5b8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edf56eb9-e136-4366-995d-696368da5b8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving economia.docx to economia.docx
# ...

# %%
import nltk
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# ...

# %%
from nltk.book import *
import matplotlib.pyplot as plt
import numpy as np
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.tokens[:10]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.']

# %%
print(len(text1))
# Out:
# 260819

# %%
text="""El presidente de la República, Martín Vizcarra, estimó este domingo que la economía del país regrese a una situación previo a la pandemia del COVID-19 en un plazo de tres años.

“Hemos hecho un análisis y vamos a regresar en tres años a la situación previa [a la pandemia del COVID-19]. La clase media que se vio afectada, retornará con esta recuperación”, indicó el mandatario en diálogo con “Punto Final”.

El mandatario aseguró que la caída de la economía terminaría este año, y a partir del próximo comenzaría la recuperación.

Vizcarra proyectó que el Producto Bruto Interno (PBI) del país caería 1% en diciembre, acumulando un desplome de 12% en todo el 2020. El próximo año iniciará el rebote por un efecto estadístico.

“Hemos llegado a bajar 40% en el mes de abril. Cada mes estamos subiendo. A fin de año vamos a llegar casi a cero. A partir de ahí, todo es crecer”, subrayó el jefe del Estado.

“El crecimiento del segundo trimestre del próximo año, va a estar largamente por sobre lo que teníamos. Vamos a dejar encaminado para que mi sucesor, cuando asuma la presidencia el 28 de julio de 2021, encuentre todo en crecimiento”, añadió."""

# %% [markdown]
# Son todas las palabras que se repiten , y no hay muchas para la riqueza lexica

# %%
# Longitud del vocabulario: Construir el vocabulario (identificar las palabras unicas que hay en el libro)
# https://docs.python.org/2/library/sets.html
vocabulario = sorted(set(text))
vocabulario[1000:1010]
# Out:
# []

# %%
# Riqueza Léxica: Calcular
rl = len(vocabulario)/len(text)
print(rl)
# Out:
# 0.05318221447253706

# %% [markdown]
# No tiene riqueza lexica el parrafo escrito por el comercio

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text1.count('monster')/len(text)
print(pc)
# Out:
# 4.272013949433305

# %% [markdown]
# Se tiene el porcenjate de palabras que ocupa en el artículo

# %%
apariciones_monster = text.count('presidente')
print(apariciones_monster)
# Out:
# 1

# %% [markdown]
# cantidada de aparicones de la palabra "presidente"

# %%
apariciones_monster = text.count('Producto Bruto')
print(apariciones_monster)
# Out:
# 1

# %% [markdown]
# Camntiadad de veces que aparece "producto Bruto" en el articulo de noticuia.

# %%
apariciones_monster = text.count('el')
print(apariciones_monster)
# Out:
# 15

# %% [markdown]
# cantidad de veces que aparece el articulo "el"
