# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhonn2021/Na-ve-Bees_-Deep-Learning-with-Images/blob/master/TokenizandoTextos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **## ANALIZANDO LOS LIBROS FALTANTES**

# %%
import nltk
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# ...

# %%
from nltk.book import *
import matplotlib.pyplot as plt
import numpy as np
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# # **# AHORA EL TEXTO 2**

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
text2.tokens[:20]
# Out:
# ['[',
#  'Sense',
#  'and',
#  'Sensibility',
#  'by',
#  'Jane',
#  'Austen',
#  '1811',
#  ']',
#  'CHAPTER',
#  '1',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in']

# %%
print(len(text2))
# Out:
# 141576

# %%
vocabulario = sorted(set(text2))
vocabulario[1000:1020]
# Out:
# ['amply',
#  'amuse',
#  'amused',
#  'amusement',
#  'amusements',
#  'amusing',
#  'an',
#  'ancient',
#  'and',
#  'anew',
#  'angel',
#  'anger',
#  'angrily',
#  'angry',
#  'anguish',
#  'animated',
#  'animating',
#  'animation',
#  'ankle',
#  'ankles']

# %%
rl = len(vocabulario)/len(text2)
print(rl)
# Out:
# 0.04826383002768831

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text1.count('angel')/len(text2)
print(pc)
# Out:
# 0.004238006441769792

# %%
apariciones_angel = text2.count('angel')
print(apariciones_angel)
# Out:
# 3

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text2):
  dic[palabra] = text2.count(palabra)
dic
# Out:
# {'sources': 2,
#  'steep': 3,
#  'pleasure': 67,
#  'warmth': 17,
#  'mile': 4,
#  'finger': 1,
#  'danger': 22,
#  'pursuit': 4,
#  'had': 969,
#  'reality': 3,
#  'pain': 25,
#  'road': 8,
#  'procuring': 4,
#  'disclosure': 1,
#  'referred': 2,
#  'delight': 24,
#  'dreadfully': 3,
#  'lady': 43,
#  'dresses': 1,
#  'brush': 1,
#  'ineffectual': 1,
#  'interference': 1,
#  'grieves': 1,
#  'reseated': 1,
#  'encroachments': 1,
#  'deserts': 2,
#  'Sometimes': 5,
#  'Impudence': 1,
#  'larger': 2,
#  'Ah': 9,
#  'oldest': 1,
#  'imagined': 8,
#  'crime': 3,
#  'overpowering': 1,
#  'half': 55,
#  'unprincipled': 3,
#  'agitation': 17,
#  'rings': 1,
#  'drawings': 4,
#  'Cassino': 1,
#  'playfulness': 1,
#  'shameless': 1,
#  'worsted': 1,
#  'necessity': 18,
#  'witty': 1,
#  'relieve': 3,
#  'ornament': 1,
#  'Cleveland': 27,
#  'interviews': 1,
#  'pupil': 1,
#  'insincere': 1,
#  'declined': 7,
#  'unanswerable': 2,
#  'human': 4,
#  'picturesque': 7,
#  '23': 1,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text2)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['angel']
# Out:
# 3

# %% [markdown]
# # **# AHORA EL TEXTO 3**

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %%
text3.tokens[:20]
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.',
#  'And',
#  'the',
#  'earth',
#  'was',
#  'without',
#  'form',
#  ',',
#  'and',
#  'void']

# %%
print(len(text3))
# Out:
# 44764

# %%
vocabulario = sorted(set(text3))
vocabulario[1000:1020]
# Out:
# ['colours',
#  'colt',
#  'colts',
#  'come',
#  'comest',
#  'cometh',
#  'comfort',
#  'comforted',
#  'comi',
#  'coming',
#  'command',
#  'commanded',
#  'commanding',
#  'commandment',
#  'commandments',
#  'commended',
#  'committed',
#  'commune',
#  'communed',
#  'communing']

# %%
rl = len(vocabulario)/len(text3)
print(rl)
# Out:
# 0.06230453042623537

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text3.count('come')/len(text3)
print(pc)
# Out:
# 0.1496738450540613

# %%
apariciones_come = text3.count('come')
print(apariciones_come)
# Out:
# 67

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text3):
  dic[palabra] = text3.count(palabra)
dic
# Out:
# {';': 605,
#  'horses': 1,
#  'Cainan': 5,
#  'pleasure': 1,
#  'observed': 1,
#  'separated': 3,
#  'changed': 3,
#  'communed': 5,
#  'toward': 19,
#  'Jubal': 1,
#  'tongue': 1,
#  'wittingly': 1,
#  'had': 139,
#  'now': 56,
#  'mercy': 4,
#  'creeping': 9,
#  'couched': 1,
#  'oversig': 1,
#  'Thorns': 1,
#  'kneel': 1,
#  'keeper': 5,
#  'speckl': 1,
#  'thereon': 2,
#  'Do': 3,
#  'whose': 16,
#  'Alvan': 1,
#  'delight': 1,
#  'spices': 1,
#  'wi': 1,
#  'scattered': 2,
#  'basket': 2,
#  'Midianites': 2,
#  'commended': 1,
#  'bear': 13,
#  'speed': 1,
#  'Fear': 3,
#  'hunting': 1,
#  'Beor': 1,
#  'instruments': 1,
#  'lights': 3,
#  'mock': 2,
#  'wick': 1,
#  'Ishmael': 17,
#  'hast': 52,
#  'liveth': 1,
#  'imagined': 1,
#  'shear': 2,
#  'waxed': 3,
#  'half': 1,
#  '(': 6,
#  'fatness': 2,
#  'comi': 1,
#  'Moriah': 1,
#  'violence': 2,
#  'Ammon': 1,
#  'mouths': 1,
#  'Methusael': 1,
#  'prayed': 1,
#  'captives': 1,
#  'leaped': 1,
#  'belly': 1,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text3)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [(',', 3681),
#  ('and', 2428),
#  ('the', 2411),
#  ('of', 1358),
#  ('.', 1315),
#  ('And', 1250),
#  ('his', 651),
#  ('he', 648),
#  ('to', 611),
#  (';', 605),
#  ('unto', 590),
#  ('in', 588),
#  ('that', 509),
#  ('I', 484),
#  ('said', 476),
#  ('him', 387),
#  ('a', 342),
#  ('my', 325),
#  ('was', 317),
#  ('for', 297)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['come']
# Out:
# 67

# %% [markdown]
# # **# AHORA EL TEXTO 4**

# %%
text4
# Out:
# <Text: Inaugural Address Corpus>

# %%
text4.tokens[:20]
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':',
#  'Among',
#  'the',
#  'vicissitudes',
#  'incident',
#  'to',
#  'life',
#  'no']

# %%
print(len(text4))
# Out:
# 149797

# %%
vocabulario = sorted(set(text4))
vocabulario[1000:1020]
# Out:
# ['Spanish',
#  'Speaker',
#  'Splendid',
#  'St',
#  'Stages',
#  'Standing',
#  'Stars',
#  'Start',
#  'Starting',
#  'State',
#  'States',
#  'Steadfast',
#  'Stennis',
#  'Steps',
#  'Still',
#  'Stonewall',
#  'Stripped',
#  'Strong',
#  'Subordinate',
#  'Such']

# %%
rl = len(vocabulario)/len(text4)
print(rl)
# Out:
# 0.04826383002768831

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text4.count('Start')/len(text4)
print(pc)
# Out:
# 0.0006675701115509657

# %%
apariciones_Start = text2.count('Start')
print(apariciones_Start)
# Out:
# 0

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text4):
  dic[palabra] = text4.count(palabra)
dic
# Out:
# {'sources': 11,
#  'appalled': 1,
#  'pleasure': 5,
#  'warmth': 1,
#  'swill': 1,
#  'danger': 40,
#  'Michelle': 1,
#  'productivity': 7,
#  'apply': 9,
#  'Beneath': 1,
#  'pursuit': 11,
#  'brotherhood': 6,
#  'shortcuts': 1,
#  'Especially': 2,
#  'had': 130,
#  'reality': 8,
#  'hurtful': 1,
#  'Plainly': 1,
#  'Michael': 1,
#  'pain': 6,
#  'road': 13,
#  'immigration': 6,
#  'intangible': 1,
#  'outrage': 2,
#  'referred': 3,
#  'delight': 2,
#  'entrepreneurial': 1,
#  'annoyance': 3,
#  'ineffectual': 1,
#  'conservation': 4,
#  'interference': 13,
#  'specifying': 1,
#  'Justice': 23,
#  'encroachments': 2,
#  'deserts': 3,
#  'Sometimes': 4,
#  'instruments': 7,
#  'venerated': 3,
#  'lights': 7,
#  'larger': 15,
#  'indicate': 2,
#  'Love': 1,
#  '1980': 2,
#  'invoked': 1,
#  'Amidst': 1,
#  'oldest': 2,
#  'States': 329,
#  'squared': 1,
#  '4th': 1,
#  'crime': 13,
#  'half': 16,
#  'agitation': 10,
#  'ripped': 1,
#  'displaying': 1,
#  'impassioned': 1,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text4)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [('the', 9446),
#  ('of', 7087),
#  (',', 7045),
#  ('and', 5146),
#  ('.', 4856),
#  ('to', 4414),
#  ('in', 2561),
#  ('a', 2184),
#  ('our', 2021),
#  ('that', 1748),
#  ('be', 1483),
#  ('is', 1448),
#  ('we', 1211),
#  ('for', 1110),
#  ('by', 1053),
#  ('it', 1028),
#  ('have', 1008),
#  ('which', 1006),
#  ('not', 949),
#  ('will', 909)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['Start']
# Out:
# 1

# %% [markdown]
# # **# AHORA EL TEXTO 5**

# %%
text5
# Out:
# <Text: Chat Corpus>

# %%
text5.tokens[:20]
# Out:
# ['now',
#  'im',
#  'left',
#  'with',
#  'this',
#  'gay',
#  'name',
#  ':P',
#  'PART',
#  'hey',
#  'everyone',
#  'ah',
#  'well',
#  'NICK',
#  ':',
#  'U7',
#  'U7',
#  'is',
#  'a',
#  'gay']

# %%
print(len(text5))
# Out:
# 45010

# %%
vocabulario = sorted(set(text5))
vocabulario[1000:1020]
# Out:
# ['NO',
#  'NONE',
#  'NOT',
#  'NOTICE',
#  'NTMN',
#  'NY',
#  'Nadda',
#  'Naples',
#  'Nashville',
#  'Need',
#  'Nevermind',
#  'New',
#  'News',
#  'Nice',
#  'Niceeee',
#  'Niceeeee',
#  'Nickelback',
#  'Night',
#  'Niters',
#  'No']

# %%
rl = len(vocabulario)/len(text5)
print(rl)
# Out:
# 0.04826383002768831

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text5.count('new')/len(text5)
print(pc)
# Out:
# 0.04443457009553432

# %%
apariciones_new = text5.count('new')
print(apariciones_new)
# Out:
# 20

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text5):
  dic[palabra] = text5.count(palabra)
dic
# Out:
# {'': 1,
#  'queen': 3,
#  'refrains': 1,
#  'lucifuge': 3,
#  'finger': 1,
#  '55%': 1,
#  'danger': 1,
#  'Shore': 1,
#  'licks': 3,
#  'nuttin': 1,
#  'had': 50,
#  'reality': 1,
#  'shaun': 1,
#  'pain': 4,
#  'road': 3,
#  'prolly': 8,
#  '((((((((((((((((((((((((': 1,
#  'spaces': 1,
#  'umm': 4,
#  'lady': 8,
#  '<<<<<<<<<<<<<<': 1,
#  'innocense': 1,
#  'rey': 1,
#  'Jones': 1,
#  'chews': 1,
#  'Love': 2,
#  'lights': 1,
#  'rofl': 2,
#  '1980': 1,
#  'Ah': 1,
#  'Oklahoma': 1,
#  'oldest': 1,
#  '14-16': 1,
#  'half': 3,
#  'NICK': 24,
#  'crust': 1,
#  'puff': 4,
#  'cuffed': 1,
#  'Heys': 1,
#  'daniel': 1,
#  'Cleveland': 1,
#  ']]]]]]]]]]]]]]]]]]]]]': 1,
#  'promoter': 1,
#  'U23': 35,
#  ';]': 1,
#  'Perception': 1,
#  'Soilwork': 1,
#  'uyes': 1,
#  'Dawnstar': 4,
#  'iamahotnipwithpics': 1,
#  'hawaii': 5,
#  'que': 2,
#  'aww': 11,
#  'human': 2,
#  'bomb': 1,
#  '23': 4,
#  'AHHAH': 1,
#  'elo': 2,
#  'sumfin': 1,
#  'answer': 7,
#  'corner': 12,
#  'going': 27,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text5)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [('.', 1268),
#  ('JOIN', 1021),
#  ('PART', 1016),
#  ('?', 737),
#  ('lol', 704),
#  ('to', 658),
#  ('i', 648),
#  ('the', 646),
#  ('you', 635),
#  (',', 596),
#  ('I', 576),
#  ('a', 568),
#  ('hi', 546),
#  ('me', 415),
#  ('...', 412),
#  ('is', 372),
#  ('..', 361),
#  ('in', 357),
#  ('ACTION', 346),
#  ('!', 342)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['new']
# Out:
# 20

# %% [markdown]
# # **# AHORA EL TEXTO 6**

# %%
text6
# Out:
# <Text: Monty Python and the Holy Grail>

# %%
text6.tokens[:20]
# Out:
# ['SCENE',
#  '1',
#  ':',
#  '[',
#  'wind',
#  ']',
#  '[',
#  'clop',
#  'clop',
#  'clop',
#  ']',
#  'KING',
#  'ARTHUR',
#  ':',
#  'Whoa',
#  'there',
#  '!',
#  '[',
#  'clop',
#  'clop']

# %%
print(len(text6))
# Out:
# 16967

# %%
vocabulario = sorted(set(text6))
vocabulario[1000:1020]
# Out:
# ['dress',
#  'dressed',
#  'dresser',
#  'dressing',
#  'drilllll',
#  'drink',
#  'dub',
#  'duck',
#  'dull',
#  'dungeon',
#  'dunno',
#  'duty',
#  'dying',
#  'dynamite',
#  'e',
#  'each',
#  'earth',
#  'earthquakes',
#  'easily',
#  'east']

# %%
rl = len(vocabulario)/len(text6)
print(rl)
# Out:
# 0.1276595744680851

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text6.count('duck')/len(text6)
print(pc)
# Out:
# 0.029468969175458243

# %%
apariciones_duck = text6.count('duck')
print(apariciones_duck)
# Out:
# 5

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text6):
  dic[palabra] = text6.count(palabra)
dic
# Out:
# {';': 4,
#  'Divine': 1,
#  'eis': 7,
#  'grail': 5,
#  'mile': 1,
#  'goodem': 1,
#  'changed': 3,
#  'danger': 2,
#  'had': 13,
#  'now': 12,
#  'mercy': 1,
#  'closest': 1,
#  'Torment': 1,
#  'howl': 5,
#  'oooh': 1,
#  'quest': 13,
#  'nnniggets': 1,
#  'Practice': 1,
#  'stew': 1,
#  'keeper': 1,
#  'Do': 4,
#  'whose': 2,
#  'crone': 1,
#  'haaa': 1,
#  'object': 1,
#  'pweeng': 2,
#  'lady': 2,
#  'brush': 1,
#  'longer': 3,
#  'speed': 2,
#  'badger': 1,
#  'Ah': 7,
#  'hast': 1,
#  'witch': 37,
#  'half': 1,
#  'logically': 1,
#  '(': 3,
#  'perilous': 1,
#  'smack': 1,
#  'violence': 2,
#  'Court': 2,
#  'May': 2,
#  'p': 1,
#  'Does': 1,
#  'convinced': 1,
#  'Yapping': 1,
#  'relics': 1,
#  'day': 2,
#  'uuup': 1,
#  'knights': 10,
#  'science': 1,
#  'tired': 1,
#  'liver': 1,
#  'cover': 1,
#  'earthquakes': 1,
#  'great': 5,
#  'Recently': 1,
#  'Britain': 1,
#  'footwork': 1,
#  'Packing': 1,
#  'leads': 2,
#  '23': 1,
#  'floats': 3,
#  'BLACK': 32,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text6)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [(':', 1197),
#  ('.', 816),
#  ('!', 801),
#  (',', 731),
#  ("'", 421),
#  ('[', 319),
#  (']', 312),
#  ('the', 299),
#  ('I', 255),
#  ('ARTHUR', 225),
#  ('?', 207),
#  ('you', 204),
#  ('a', 188),
#  ('of', 158),
#  ('--', 148),
#  ('to', 144),
#  ('s', 141),
#  ('and', 135),
#  ('#', 127),
#  ('...', 118)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['duck']
# Out:
# 5

# %% [markdown]
# # **# AHORA EL TEXTO 7**

# %%
text7
# Out:
# <Text: Wall Street Journal>

# %%
text7.tokens[:20]
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.',
#  'Mr.',
#  'Vinken']

# %%
print(len(text7))
# Out:
# 141576

# %%
vocabulario = sorted(set(text7))
vocabulario[1000:1020]
# Out:
# ['3.9',
#  '30',
#  '30,000',
#  '30,537',
#  '30,841',
#  '30-day',
#  '30-minute',
#  '30-point',
#  '30-share',
#  '30-year',
#  '30.6',
#  '30.9',
#  '300',
#  '300,000',
#  '300-113',
#  '300-a-share',
#  '300-day',
#  '301',
#  '3057',
#  '306']

# %%
rl = len(vocabulario)/len(text7)
print(rl)
# Out:
# 0.12324685128531129

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text7.count('poit')/len(text7)
print(pc)
# Out:
# 0.0

# %%
apariciones_point = text2.count('point')
print(apariciones_point)
# Out:
# 38

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text7):
  dic[palabra] = text7.count(palabra)
dic
# Out:
# {'Lobo': 1,
#  'sources': 8,
#  '1,298': 1,
#  'steep': 2,
#  'binge': 1,
#  'Key': 2,
#  'productivity': 1,
#  'apply': 4,
#  'retractable': 1,
#  '98': 4,
#  'Kingdom': 3,
#  'had': 165,
#  'reality': 4,
#  'Pepperdine': 1,
#  'Showa': 1,
#  '1928-33': 1,
#  'Michael': 17,
#  'pain': 1,
#  '87-store': 1,
#  'road': 4,
#  'stresses': 1,
#  'Coincident': 1,
#  'disclosure': 2,
#  'Lazzaroni': 1,
#  'spaces': 2,
#  '*T*-208': 1,
#  'referred': 6,
#  'prohibits': 3,
#  'outrage': 1,
#  '144': 1,
#  'Alfred': 3,
#  'lady': 2,
#  'catch-up': 1,
#  '*T*-256': 1,
#  'Steelworkers': 1,
#  'ire': 1,
#  'mundane': 1,
#  'Taurus': 2,
#  'Rockwell': 5,
#  'interference': 3,
#  'Jones': 20,
#  '86': 1,
#  '9.625': 1,
#  'Dompierre': 1,
#  'Justice': 13,
#  'discounts': 1,
#  'stiffer': 1,
#  'instruments': 5,
#  'Sometimes': 2,
#  'indicate': 3,
#  'lights': 2,
#  'larger': 7,
#  '1980': 1,
#  'Oklahoma': 2,
#  'oldest': 2,
#  'States': 5,
#  'Germans': 2,
#  '*T*-86': 1,
#  'gauge': 2,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text7)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [(',', 4885),
#  ('the', 4045),
#  ('.', 3828),
#  ('of', 2319),
#  ('to', 2164),
#  ('a', 1878),
#  ('in', 1572),
#  ('and', 1511),
#  ('*-1', 1123),
#  ('0', 1099),
#  ('*', 965),
#  ("'s", 864),
#  ('for', 817),
#  ('that', 807),
#  ('*T*-1', 806),
#  ('*U*', 744),
#  ('$', 718),
#  ('The', 717),
#  ('``', 702),
#  ("''", 684)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['point']
# Out:
# 29

# %% [markdown]
# # **# AHORA EL TEXTO 8**

# %%
text8
# Out:
# <Text: Personals Corpus>

# %%
text8.tokens[:20]
# Out:
# ['25',
#  'SEXY',
#  'MALE',
#  ',',
#  'seeks',
#  'attrac',
#  'older',
#  'single',
#  'lady',
#  ',',
#  'for',
#  'discreet',
#  'encounters',
#  '.',
#  '35YO',
#  'Security',
#  'Guard',
#  ',',
#  'seeking',
#  'lady']

# %%
print(len(text8))
# Out:
# 4867

# %%
vocabulario = sorted(set(text8))
vocabulario[1000:1020]
# Out:
# ['southern',
#  'special',
#  'speed',
#  'spend',
#  'spoilt',
#  'sport',
#  'sports',
#  'standing',
#  'still',
#  'ston',
#  'strictly',
#  'strings',
#  'strong',
#  'student',
#  'stylish',
#  'sub',
#  'subs',
#  'suburbs',
#  'sufficiencies',
#  'suited']

# %%
rl = len(vocabulario)/len(text8)
print(rl)
# Out:
# 0.22765564002465585

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text8.count('sport')/len(text8)
print(pc)
# Out:
# 0.04109307581672488

# %%
apariciones_sport = text2.count('sport')
print(apariciones_sport)
# Out:
# 2

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text8):
  dic[palabra] = text8.count(palabra)
dic
# Out:
# {'romantic': 4,
#  'candlelight': 1,
#  'kissing': 1,
#  'ATHLETIC': 1,
#  'intelligent': 3,
#  'horses': 1,
#  'red': 1,
#  'loyal': 2,
#  'vegetarian': 2,
#  'modern': 1,
#  'Must': 7,
#  'Asian': 5,
#  'fishing': 8,
#  'def': 1,
#  '65': 3,
#  'ties': 5,
#  'important': 1,
#  'cm': 1,
#  'region': 1,
#  'from': 2,
#  '70s': 1,
#  'WELL': 1,
#  'football': 1,
#  'TAINING': 1,
#  'reply': 2,
#  'ARE': 2,
#  'GOSH': 1,
#  'at': 9,
#  'Clare': 1,
#  'Caring': 1,
#  'With': 2,
#  'morals': 1,
#  'n': 11,
#  'food': 1,
#  'over': 1,
#  'drinker': 13,
#  'be': 13,
#  'd': 3,
#  'Nationality': 1,
#  '34': 1,
#  'bowling': 1,
#  'f': 13,
#  'without': 1,
#  'brain': 1,
#  'if': 2,
#  'LIMESTONE': 1,
#  'Rship': 1,
#  'down': 3,
#  'Olive': 1,
#  'MT': 1,
#  'loving': 6,
#  'naughty': 1,
#  'lady': 68,
#  'females': 1,
#  'com': 1,
#  '54y': 1,
#  '",': 2,
#  'suburbs': 5,
#  'pls': 2,
#  '30s': 8,
#  'perm': 2,
#  'PENINSULA': 1,
#  'green': 1,
#  'speed': 1,
#  'city': 1,
#  'Taurus': 1,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text8)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [(',', 539),
#  ('.', 353),
#  ('/', 110),
#  ('for', 99),
#  ('and', 74),
#  ('to', 74),
#  ('lady', 68),
#  ('-', 66),
#  ('seeks', 60),
#  ('a', 52),
#  ('with', 44),
#  ('S', 36),
#  ('ship', 33),
#  ('&', 30),
#  ('relationship', 29),
#  ('fun', 28),
#  ('in', 27),
#  ('slim', 27),
#  ('build', 27),
#  ('o', 26)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['sport']
# Out:
# 2

# %% [markdown]
# # **# AHORA EL TEXTO 9**

# %%
text9
# Out:
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>

# %%
text9.tokens[:20]
# Out:
# ['[',
#  'The',
#  'Man',
#  'Who',
#  'Was',
#  'Thursday',
#  'by',
#  'G',
#  '.',
#  'K',
#  '.',
#  'Chesterton',
#  '1908',
#  ']',
#  'To',
#  'Edmund',
#  'Clerihew',
#  'Bentley',
#  'A',
#  'cloud']

# %%
print(len(text9))
# Out:
# 69213

# %%
vocabulario = sorted(set(text9))
vocabulario[1000:1020]
# Out:
# ['amendment',
#  'amiability',
#  'amiable',
#  'amiably',
#  'amid',
#  'among',
#  'amply',
#  'amuse',
#  'amused',
#  'an',
#  'anarchic',
#  'anarchism',
#  'anarchist',
#  'anarchists',
#  'anarchy',
#  'ancestral',
#  'ancient',
#  'and',
#  'angel',
#  'angelic']

# %%
rl = len(vocabulario)/len(text9)
print(rl)
# Out:
# 0.0983485761345412

# %%
# Porcentaje que una palabra que ocupa en un texto
pc = 100*text9.count('angel')/len(text9)
print(pc)
# Out:
# 0.0014448152803664051

# %%
apariciones_angel = text9.count('angel')
print(apariciones_angel)
# Out:
# 1

# %%
# METODO NO recomendable para corpus grandes
dic = {}
for palabra in set(text9):
  dic[palabra] = text9.count(palabra)
dic
# Out:
# {'steep': 5,
#  'pleasure': 11,
#  'warmth': 2,
#  'finger': 6,
#  'mile': 3,
#  'Parkers': 1,
#  'danger': 2,
#  'tacitly': 1,
#  'gloved': 1,
#  'pursuit': 1,
#  'brotherhood': 3,
#  'had': 427,
#  'fulness': 1,
#  'reality': 2,
#  'Saumur': 2,
#  'dehumanised': 1,
#  'swaying': 1,
#  'pain': 5,
#  'serf': 1,
#  'road': 29,
#  'paradoxes': 1,
#  'crumpled': 1,
#  'outrage': 2,
#  'Catch': 1,
#  'lady': 4,
#  'dresses': 1,
#  'interference': 1,
#  'hunting': 3,
#  'instruments': 1,
#  'Sometimes': 3,
#  'lights': 7,
#  'larger': 8,
#  'Ah': 3,
#  'aslant': 2,
#  'realised': 8,
#  'oldest': 2,
#  'imagined': 2,
#  'revolting': 2,
#  'crime': 15,
#  'overpowering': 1,
#  'dispassionately': 1,
#  'half': 37,
#  'bush': 2,
#  'ripped': 2,
#  'saints': 1,
#  'puff': 2,
#  'cabs': 7,
#  'incredibly': 2,
#  'witty': 2,
#  'plunge': 1,
#  'moonshine': 1,
#  'declined': 1,
#  'clot': 1,
#  'jaws': 1,
#  'flings': 1,
#  'unanswerable': 1,
#  'Might': 2,
#  'human': 34,
#  'bomb': 15,
# ...

# %%
# NLTK tiene un metodo muy eficiente
fdist = FreqDist(text9)

# %%
#Ver las palabras más comunes
fdist.most_common(20)
# Out:
# [(',', 3488),
#  ('the', 3291),
#  ('.', 2717),
#  ('a', 1713),
#  ('of', 1710),
#  ('and', 1568),
#  ('"', 1336),
#  ('to', 1045),
#  ('in', 888),
#  ('I', 885),
#  ('he', 858),
#  ('that', 841),
#  ('his', 765),
#  ('was', 716),
#  ('you', 580),
#  ('it', 565),
#  ('with', 544),
#  ('Syme', 515),
#  (',"', 507),
#  ('said', 507)]

# %%
#Plotear las distribuciones
fdist.plot(20)

# %%
#Cuantas veces se repite una palabra
fdist['angel']
# Out:
# 1

# %% [markdown]
# ### **ESO ES TODO UFF**
